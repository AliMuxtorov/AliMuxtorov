# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('top_brend_in_a_world.csv')

# %%
dataset
# Out:
#    unvon      tovar tovar_qiymati 1_yr_qiymati_o'zgarishi tovar_daromadi  \
# 0      1      Apple      $241.20                      17%       $260.20
# 1      2     Google      $207.50                      24%       $145.60
# 2      3  Microsoft      $162.90                      30%       $125.80
# 3      4     Amazon      $135.40                      40%       $260.50
# 4      5   Facebook       $70.30                     -21%        $49.70
# 5      6  Coca-Cola       $64.40                       9%        $25.20
# 6      7     Disney       $61.30                      18%        $38.70
# 7      8    Samsung       $50.40                      -5%       $209.50
#
#         sanoat
# 0  texnologiya
# 1  Texnologiya
# 2  Texnologiya
# 3  Texnologiya
# 4  Texnologiya
# 5  Ichimliklar
# 6   Bo'sh vaqt
# 7  Texnologiya

# %%
top_brands = dataset.tovar
top_world = dataset.tovar_daromadi

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.barh(top_brands,top_world)
# Out:
# <BarContainer object of 8 artists>

# %%
top_logo = dataset.tovar
top_market = dataset.tovar_qiymati

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.plot(top_logo,top_market)

# %%
market_tovar = dataset.tovar
tovar_qiymati = dataset.tovar_qiymati

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.scatter(market_tovar,tovar_qiymati)

# %%
top_in_a_world = dataset.tovar
tovar_top= dataset.tovar_daromadi

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.step(top_in_a_world,tovar_top)

# %%
plt.errorbar(top_in_a_world,tovar_top)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
top_the_world = dataset.tovar
top_news = dataset.unvon

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.errorbar(top_the_world,top_news)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
top_brend = dataset.tovar
top_news = dataset.tovar_daromadi

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.barh(top_brend,top_news)
# Out:
# <BarContainer object of 8 artists>

# %%
top_in_world = dataset.tovar
tovar_top= dataset.tovar_daromadi

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.step(top_in_a_world,tovar_top)

# %%
top_in_a_world = dataset.tovar
tovar_top= dataset.tovar_daromadi

plt.title("Dunyodagi Top 8 brendlar analizi")
plt.xlabel("Brendning xalqaro pog'onalari")
plt.ylabel("Brendlar ko'rsatgichi")

plt.step(top_in_a_world,tovar_top)
